# %%
import pandas as pd

# %%
df = pd.read_csv('stops.txt')

# %%
df.head(10)
# Out:
#    stop_id  stop_code                                        stop_name  \
# 0    23060      23060                                  Alameda Station
# 1    18675      18675                          Wadsworth & Hampden PnR
# 2    18898      18898                                  Bergen Park PnR
# 3    26156      26156  40th Ave & Airport Blvd-Gateway Park Stn Gate C
# 4    33791      33791                   Boulder Church of The Nazarene
# 5    11651      11651                           72nd Ave & Brighton Rd
# 6    33789      33789                              27th Way / Broadway
# 7    12439      12439                              Broadway & 27th Way
# 8    20352      20352                                      Genesee PnR
# 9    33820      33820                                         Longmont
#
#                        stop_desc   stop_lat    stop_lon  zone_id  stop_url  \
# 0  Vehicles Travelling Southeast  39.708196 -104.992785      NaN       NaN
# ...

# %%
routes = pd.read_csv('routes.txt')

# %%
routes.head()
# Out:
#   route_id route_short_name         route_long_name  \
# 0        0                0          South Broadway
# 1       0L               0L  South Broadway Limited
# 2        1                1              1st Avenue
# 3       10               10        East 12th Avenue
# 4      100              100          Kipling Street
#
#                                    route_desc  route_type  \
# 0  This Route Travels Northbound & Southbound           3
# 1  This Route Travels Northbound & Southbound           3
# 2    This Route Travels Eastbound & Westbound           3
# 3    This Route Travels Eastbound & Westbound           3
# 4  This Route Travels Northbound & Southbound           3
#
#                                    route_url route_color route_text_color
# 0  http://www.rtd-denver.com/Schedules.shtml      0076CE           FFFFFF
# 1  http://www.rtd-denver.com/Schedules.shtml      0076CE           FFFFFF
# 2  http://www.rtd-denver.com/Schedules.shtml      0076CE           FFFFFF
# ...

# %%
routes
# Out:
#     route_id route_short_name  \
# 0          0                0
# 1         0L               0L
# 2          1                1
# 3         10               10
# 4        100              100
# 5       100L             100L
# 6       101C                C
# 7       101D                D
# 8       101E                E
# 9       101F                F
# 10      101H                H
# 11      103W                W
# 12       104              104
# 13      104X             104X
# 14       105              105
# 15        11               11
# 16       112              112
# 17      113B                B
# 18      116L             116L
# 19      116X             116X
# 20        12               12
# 21       120              120
# 22      120X             120X
# 23       121              121
# 24      122X             122X
# 25       128              128
# 26       130              130
# 27       131              131
# 28       133              133
# 29       135              135
# ...
